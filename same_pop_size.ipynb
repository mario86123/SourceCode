# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_bar_chart(problem_name, arpd_lst):
    model = ['MR', 'MST', 'MSTME', 'GMC', 'MU']
#     ARPD = [0.044, 0.038, 0.131, 0.074, 0.053]

    x = np.arange(len(model))

    plt.bar(x, arpd_lst, color=['red', 'orange', 'gold', 'green', 'blue'])
    
    for index,data in enumerate(arpd_lst):
        plt.text(x=index-0.5 , y =data+0.001 , s=f"{data}" , fontdict=dict(fontsize=25))

    plt.title(problem_name, fontsize=30)    

    plt.xticks(x, model, fontsize=20)
    # plt.xlabel('model', fontsize=20)
    
    plt.yticks(fontsize=15)
    plt.ylabel('ARPD', fontsize=20)

    plt.rcParams["figure.figsize"] = (8,8)
    plt.show()

# %%
plot_bar_chart('SDF', [0.0, 0.0, 0.0, 41.7, 81.5])

# %%
plot_bar_chart('TSP', [9.0, 31.3, 41.0, 76.9, 175.7])

# %%
plot_bar_chart('QAP', [13.2, 12.7, 9.4, 5.3, 11.5])

# %%
plot_bar_chart('PFSP', [3.4, 3.2, 3.5, 4.8, 10.7])

# %%
plot_bar_chart('LOP', [5.7, 0.5, 0.6, 1.1, 9.9])

# %%
plot_bar_chart('VRP', [4.4, 13.0, 12.2, 28.6, 105.7])
