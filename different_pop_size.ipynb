# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_bar_chart(problem_name, arpd_lst):
    model = ['MR', 'MST', 'MSTME', 'EO', 'ET5', 'NO', 'NT5']
#     ARPD = [0.044, 0.038, 0.131, 0.074, 0.053]

    x = np.arange(len(model))

    plt.bar(x, arpd_lst, color=['red', 'orange', 'gold', 'green', 'cornflowerblue', 'blue', 'purple'])
    
    for index,data in enumerate(arpd_lst):
        plt.text(x=index-0.5 , y =data+0.001 , s=f"{data}" , fontdict=dict(fontsize=25))

    plt.title(problem_name, fontsize=30)    

    plt.xticks(x, model, fontsize=20)
    # plt.xlabel('model', fontsize=20)
    
    plt.yticks(fontsize=15)
    plt.ylabel('ARPD', fontsize=20)

    plt.rcParams["figure.figsize"] = (8,8)
    plt.show()

# %%
plot_bar_chart('SDF', [0.0, 0.0, 0.0, 84.3, 57.0, 17.3, 16.3])

# %%
plot_bar_chart('TSP', [5.3, 25.8, 35.3, 11.2, 0.0, 33.1, 166.0])

# %%
plot_bar_chart('QAP', [13.1, 4.4, 3.8, 13.0, 7.4, 3.1, 8.1])

# %%
plot_bar_chart('PFSP', [3.4, 2.8, 3.2, 9.9, 4.6, 1.9, 3.1])

# %%
plot_bar_chart('LOP', [0.4, 0.3, 0.3, 1.8, 0.1, 0.2, 1.1])

# %%
plot_bar_chart('VRP', [1.2, 7.1, 7.1, 20.6, 2.9, 2.2, 49.6])
